# %%
import pandas as pd

# %%
df = pd.read_csv("../data/df_requests_cleaned.csv")
len(df)
# Out:
# /tmp/ipykernel_2639923/588516743.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/df_requests_cleaned.csv")
# 862093

# %%
X = df["DetalhamentoSolicitacao"]
len(X)
# Out:
# 862093

# %%
X.drop_duplicates()
X.dropna()
len(X)
# Out:
# 862093

# %%
df_new = df[['DetalhamentoSolicitacao', 'OrgaoDestinatario']].dropna().rename(
    columns={'DetalhamentoSolicitacao': 'x', 'OrgaoDestinatario': 'y'}
)
df_new.head()
# Out:
#                                                    x  \
# 0  solicitação processo administrativo cadastrar ...
# 1  prezar senhor enviar processo acima foto menci...
# 2  presidente associação projeto ação comunitário...
# 3        ver cópia termo acusação relatório processo
# 4  dia nome andré pievir período curso ciência bi...
#
#                                                    y
# 0                         MF - Ministério da Fazenda
# 1  ANTT – Agência Nacional de Transportes Terrestres
# 2  MDS - Ministério do Desenvolvimento e Assistên...
# 3              CVM – Comissão de Valores Mobiliários
# 4  IFPE – Instituto Federal de Educação, Ciência ...

# %%
df_new.to_csv("../data/df_requests_x_y.csv", index=False)
